# %%
from utils import sheet_to_dataframe, convert_islamic_date
import pandas as pd
import numpy as np
import warnings
from fuzzywuzzy import fuzz
from fuzzywuzzy import process


warnings.simplefilter('ignore')
pd.pandas.set_option('display.max_columns',None)
# Out:
# /home/bee_nyah/Desktop/DATA_EPIC/Best_Nyah/venv/lib/python3.8/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
# read data from google sheet
WORKSHEETSHEET_NAME="inconsistent_data"
SHEET_URL = "https://docs.google.com/spreadsheets/d/1SUlcukpgxf6pfFQbj6DKQZXSlOhyBOSuBdbmQ2ZbhTM/edit#gid=1520648174"

data = sheet_to_dataframe(SHEET_URL,WORKSHEETSHEET_NAME)

# %%
data.head()
# Out:
#    S#                     Date                   Islamic Date Blast Day Type  \
# 0   1  Sunday-November 19-1995  25 Jumaada al-THaany 1416 A.H        Holiday
# 1   2   Monday-November 6-2000           10 SHa`baan 1421 A.H    Working Day
# 2   3     Wednesday-May 8-2002              25 safar 1423 A.H    Working Day
# 3   4      Friday-June 14-2002     3 Raby` al-THaany 1423 A.H    Working Day
# 4   5       Friday-July 4-2003     4 Jumaada al-awal 1424 A.H    Working Day
#
#   Holiday Type         Time       City Latitude Longitude     Province  \
# 0      Weekend          N/A  Islamabad   33.718   73.0718      Capital
# 1                       N/A    Karachi  24.9918   66.9911        Sindh
# 2                   7:45 AM    Karachi  24.9918   66.9911        Sindh
# 3               11:10:00 AM    Karachi  24.9918   66.9911        Sindh
# 4                       N/A     Quetta  30.2095   67.0182  Baluchistan
#
#                                             Location Location Category  \
# 0                                   Egyptian Embassy           Foreign
# 1                              office of Nawa-e-Waqt   Office Building
# 2  Pakistan Navy bus Parked outside Five Star She...             Hotel
# 3                      US Consulate Civil Lines Area           Foreign
# 4                     Imambargah MeCongy Road Quetta         Religious
#
#   Location Sensitivity Open/Closed Space Influencing Event/Event Target Type  \
# 0                 High            Closed                           Foreigner
# 1                  Low            Closed                               Media
# 2               Medium            Closed                           Foreigner
# 3                 High            Closed                           Foreigner
# 4               Medium            Closed    during Friday prayer   Religious
#
#   Targeted Sect if any Killed Min Killed Max Injured Min Injured Max  \
# 0                 None         14         15                      60
# 1                 None                     3                       3
# 2            Christian         13         15          20          40
# 3            Christian                    12                      51
# 4               Shiite         44         47                      65
#
#   No. of Suicide Blasts Explosive Weight (max)  \
# 0                     2
# 1                     1
# 2                     1                 2.5 Kg
# 3                     1                     NA
# 4                     1                     NA
#
#                                       Hospital Names Temperature(C)  \
# 0                                                            15.835
# 1                                                             23.77
# 2  1.Jinnah Postgraduate Medical Center 2. Civil ...          31.46
# 3                                                 NA          31.43
# 4  1.CMH Quetta \n2.Civil Hospital 3. Boland Medi...          33.12
#
#   Temperature(F)
# 0         60.503
# 1         74.786
# 2         88.628
# 3         88.574
# 4         91.616

# %%
data.shape
# Out:
# (496, 26)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 496 entries, 0 to 495
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   S#                       496 non-null    int64
#  1   Date                     496 non-null    object
#  2   Islamic Date             496 non-null    object
#  3   Blast Day Type           496 non-null    object
#  4   Holiday Type             496 non-null    object
#  5   Time                     496 non-null    object
#  6   City                     496 non-null    object
#  7   Latitude                 496 non-null    object
#  8   Longitude                496 non-null    object
#  9   Province                 496 non-null    object
#  10  Location                 496 non-null    object
#  11  Location Category        496 non-null    object
#  12  Location Sensitivity     496 non-null    object
#  13  Open/Closed Space        496 non-null    object
#  14  Influencing Event/Event  496 non-null    object
#  15  Target Type              496 non-null    object
#  16  Targeted Sect if any     496 non-null    object
#  17  Killed Min               496 non-null    object
#  18  Killed Max               496 non-null    object
#  19  Injured Min              496 non-null    object
#  20  Injured Max              496 non-null    object
#  21  No. of Suicide Blasts    496 non-null    object
#  22  Explosive Weight (max)   496 non-null    object
#  23  Hospital Names           496 non-null    object
#  24  Temperature(C)           496 non-null    object
#  25  Temperature(F)           496 non-null    object
# dtypes: int64(1), object(25)
# memory usage: 100.9+ KB

# %%
df = data.copy()

# %%
df.replace('', np.nan, inplace=True)
df.replace('N/A', np.nan, inplace=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 496 entries, 0 to 495
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   S#                       496 non-null    int64
#  1   Date                     496 non-null    object
#  2   Islamic Date             342 non-null    object
#  3   Blast Day Type           486 non-null    object
#  4   Holiday Type             72 non-null     object
#  5   Time                     350 non-null    object
#  6   City                     496 non-null    object
#  7   Latitude                 493 non-null    float64
#  8   Longitude                493 non-null    float64
#  9   Province                 496 non-null    object
#  10  Location                 493 non-null    object
#  11  Location Category        460 non-null    object
#  12  Location Sensitivity     460 non-null    object
#  13  Open/Closed Space        461 non-null    object
#  14  Influencing Event/Event  246 non-null    object
#  15  Target Type              470 non-null    object
#  16  Targeted Sect if any     458 non-null    object
#  17  Killed Min               350 non-null    float64
#  18  Killed Max               480 non-null    float64
#  19  Injured Min              365 non-null    float64
#  20  Injured Max              464 non-null    object
#  21  No. of Suicide Blasts    414 non-null    float64
#  22  Explosive Weight (max)   381 non-null    object
#  23  Hospital Names           397 non-null    object
#  24  Temperature(C)           491 non-null    float64
#  25  Temperature(F)           489 non-null    float64
# dtypes: float64(8), int64(1), object(17)
# memory usage: 100.9+ KB

# %%
# data types
data_type_mapping = {
    'Latitude': 'float64',
    'Temperature(C)': 'float64',
    'Temperature(F)': 'float64',
    'Killed Min': 'int64',
    'Killed Max': 'int64',
    'Injured Min': 'int64',
    'No. of Suicide Blasts': 'int64',
}
			
for col in data_type_mapping:
        df[col].fillna(-59, inplace=True)

# convert respective columns to the right types
df = df.astype(data_type_mapping)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 496 entries, 0 to 495
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   S#                       496 non-null    int64
#  1   Date                     496 non-null    object
#  2   Islamic Date             342 non-null    object
#  3   Blast Day Type           486 non-null    object
#  4   Holiday Type             72 non-null     object
#  5   Time                     350 non-null    object
#  6   City                     496 non-null    object
#  7   Latitude                 496 non-null    float64
#  8   Longitude                493 non-null    float64
#  9   Province                 496 non-null    object
#  10  Location                 493 non-null    object
#  11  Location Category        460 non-null    object
#  12  Location Sensitivity     460 non-null    object
#  13  Open/Closed Space        461 non-null    object
#  14  Influencing Event/Event  246 non-null    object
#  15  Target Type              470 non-null    object
#  16  Targeted Sect if any     458 non-null    object
#  17  Killed Min               496 non-null    int64
#  18  Killed Max               496 non-null    int64
#  19  Injured Min              496 non-null    int64
#  20  Injured Max              464 non-null    object
#  21  No. of Suicide Blasts    496 non-null    int64
#  22  Explosive Weight (max)   381 non-null    object
#  23  Hospital Names           397 non-null    object
#  24  Temperature(C)           496 non-null    float64
#  25  Temperature(F)           496 non-null    float64
# dtypes: float64(4), int64(5), object(17)
# memory usage: 100.9+ KB

# %%
df.head()
# Out:
#    S#                     Date                   Islamic Date Blast Day Type  \
# 0   1  Sunday-November 19-1995  25 Jumaada al-THaany 1416 A.H        Holiday
# 1   2   Monday-November 6-2000           10 SHa`baan 1421 A.H    Working Day
# 2   3     Wednesday-May 8-2002              25 safar 1423 A.H    Working Day
# 3   4      Friday-June 14-2002     3 Raby` al-THaany 1423 A.H    Working Day
# 4   5       Friday-July 4-2003     4 Jumaada al-awal 1424 A.H    Working Day
#
#   Holiday Type         Time       City  Latitude  Longitude     Province  \
# 0      Weekend          NaN  Islamabad   33.7180    73.0718      Capital
# 1          NaN          NaN    Karachi   24.9918    66.9911        Sindh
# 2          NaN      7:45 AM    Karachi   24.9918    66.9911        Sindh
# 3          NaN  11:10:00 AM    Karachi   24.9918    66.9911        Sindh
# 4          NaN          NaN     Quetta   30.2095    67.0182  Baluchistan
#
#                                             Location Location Category  \
# 0                                   Egyptian Embassy           Foreign
# 1                              office of Nawa-e-Waqt   Office Building
# 2  Pakistan Navy bus Parked outside Five Star She...             Hotel
# 3                      US Consulate Civil Lines Area           Foreign
# 4                     Imambargah MeCongy Road Quetta         Religious
#
#   Location Sensitivity Open/Closed Space Influencing Event/Event Target Type  \
# 0                 High            Closed                     NaN   Foreigner
# 1                  Low            Closed                     NaN       Media
# 2               Medium            Closed                     NaN   Foreigner
# 3                 High            Closed                     NaN   Foreigner
# 4               Medium            Closed    during Friday prayer   Religious
#
#   Targeted Sect if any  Killed Min  Killed Max  Injured Min Injured Max  \
# 0                 None          14          15          -59          60
# 1                 None         -59           3          -59           3
# 2            Christian          13          15           20          40
# 3            Christian         -59          12          -59          51
# 4               Shiite          44          47          -59          65
#
#    No. of Suicide Blasts Explosive Weight (max)  \
# 0                      2                    NaN
# 1                      1                    NaN
# 2                      1                 2.5 Kg
# 3                      1                     NA
# 4                      1                     NA
#
#                                       Hospital Names  Temperature(C)  \
# 0                                                NaN          15.835
# 1                                                NaN          23.770
# 2  1.Jinnah Postgraduate Medical Center 2. Civil ...          31.460
# 3                                                 NA          31.430
# 4  1.CMH Quetta \n2.Civil Hospital 3. Boland Medi...          33.120
#
#    Temperature(F)
# 0          60.503
# 1          74.786
# 2          88.628
# 3          88.574
# 4          91.616

# %%
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# %%
# Remove 'kg' suffix from the 'Explosive Weight (max)' column
df['Explosive Weight (max)'] = df['Explosive Weight (max)'].str.replace(r'[kK][gG]$', '', regex=True)
# Remove '+' from the 'Injured max' column
df["Injured Max"] = df["Injured Max"].str.replace(r'[A-Za-z+]', '', regex=True)

# %%
df['Islamic Date'].fillna('Unknown', inplace=True)
df['Holiday Type'].fillna('Unknown', inplace=True)
df['Time'].fillna('Unknown', inplace=True)
df['Hospital Names'].fillna('Unknown', inplace=True)
df['Explosive Weight (max)'].fillna('Unknown', inplace=True)
df['Blast Day Type'].fillna('Unknown', inplace=True)
df['Islamic Date'].fillna('Unknown', inplace=True)
df['Latitude'].fillna('Unknown', inplace=True)
df['Longitude'].fillna('Unknown', inplace=True)

# %%
# using fuzzy matching for location column 
def standardize_location(location_name):
    choices = df['Location'].unique()
    match, score = process.extractOne(location_name, choices, scorer=fuzz.token_sort_ratio)
    if score >= 80:
        return match
    else:
        return location_name

df['Location'] = df['Location'].astype(str)
df['Location'] = df['Location'].apply(standardize_location)

# %%
df['Location'].head()
# Out:
# 0                                     Egyptian Embassy
# 1                                office of Nawa-e-Waqt
# 2    Pakistan Navy bus Parked outside Five Star She...
# 3                        US Consulate Civil Lines Area
# 4                       Imambargah MeCongy Road Quetta
# Name: Location, dtype: object

# %%
df.head()
# Out:
#    S#       Date                   Islamic Date Blast Day Type Holiday Type  \
# 0   1 1995-11-19  25 Jumaada al-THaany 1416 A.H        Holiday      Weekend
# 1   2 2000-11-06           10 SHa`baan 1421 A.H    Working Day      Unknown
# 2   3 2002-05-08              25 safar 1423 A.H    Working Day      Unknown
# 3   4 2002-06-14     3 Raby` al-THaany 1423 A.H    Working Day      Unknown
# 4   5 2003-07-04     4 Jumaada al-awal 1424 A.H    Working Day      Unknown
#
#           Time       City  Latitude Longitude     Province  \
# 0      Unknown  Islamabad   33.7180   73.0718      Capital
# 1      Unknown    Karachi   24.9918   66.9911        Sindh
# 2      7:45 AM    Karachi   24.9918   66.9911        Sindh
# 3  11:10:00 AM    Karachi   24.9918   66.9911        Sindh
# 4      Unknown     Quetta   30.2095   67.0182  Baluchistan
#
#                                             Location Location Category  \
# 0                                   Egyptian Embassy           Foreign
# 1                              office of Nawa-e-Waqt   Office Building
# 2  Pakistan Navy bus Parked outside Five Star She...             Hotel
# 3                      US Consulate Civil Lines Area           Foreign
# 4                     Imambargah MeCongy Road Quetta         Religious
#
#   Location Sensitivity Open/Closed Space Influencing Event/Event Target Type  \
# 0                 High            Closed                     NaN   Foreigner
# 1                  Low            Closed                     NaN       Media
# 2               Medium            Closed                     NaN   Foreigner
# 3                 High            Closed                     NaN   Foreigner
# 4               Medium            Closed    during Friday prayer   Religious
#
#   Targeted Sect if any  Killed Min  Killed Max  Injured Min Injured Max  \
# 0                 None          14          15          -59         NaN
# 1                 None         -59           3          -59         NaN
# 2            Christian          13          15           20         NaN
# 3            Christian         -59          12          -59         NaN
# 4               Shiite          44          47          -59         NaN
#
#    No. of Suicide Blasts Explosive Weight (max)  \
# 0                      2                Unknown
# 1                      1                Unknown
# 2                      1                   2.5
# 3                      1                     NA
# 4                      1                     NA
#
#                                       Hospital Names  Temperature(C)  \
# 0                                            Unknown          15.835
# 1                                            Unknown          23.770
# 2  1.Jinnah Postgraduate Medical Center 2. Civil ...          31.460
# 3                                                 NA          31.430
# 4  1.CMH Quetta \n2.Civil Hospital 3. Boland Medi...          33.120
#
#    Temperature(F)
# 0          60.503
# 1          74.786
# 2          88.628
# 3          88.574
# 4          91.616
